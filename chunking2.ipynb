# %%
import pandas as pd

# %%
df = pd.read_csv("./data/recordings_data.csv")

df.head(5)
# Out:
#    Unnamed: 0                          audio_id  chunk_id  \
# 0           0  92005f1a713e47cb83667a4300eedc84         1
# 1           1  181019ba1580492687bfab6a9d8d6451         3
# 2           2  181019ba1580492687bfab6a9d8d6451         2
# 3           3  181019ba1580492687bfab6a9d8d6451         1
# 4           4  2226fca493a54603a9ec15decd26f1b1         3
#
#                                           transcript
# 0   Sir, how is the signature? Is it a hidden cop...
# 1   I have sent it in the morning. Yes, this amou...
# 2   Hello ma'am, I am Koshal speaking. Yes, pleas...
# 3   Good morning, Chester. I am Aishwarya. How ar...
# 4             Okay. Thank you so much for your time.

# %%
df = df.drop(columns=["Unnamed: 0"])

# %%
from IPython.display import Displa
# Out:
#                               audio_id  chunk_id  \
# 0     92005f1a713e47cb83667a4300eedc84         1
# 1     181019ba1580492687bfab6a9d8d6451         3
# 2     181019ba1580492687bfab6a9d8d6451         2
# 3     181019ba1580492687bfab6a9d8d6451         1
# 4     2226fca493a54603a9ec15decd26f1b1         3
# ...                                ...       ...
# 1357  3892281a35f5427caad95dac2ae6e198         5
# 1358  3892281a35f5427caad95dac2ae6e198         4
# 1359  3892281a35f5427caad95dac2ae6e198         3
# 1360  3892281a35f5427caad95dac2ae6e198         2
# 1361  3892281a35f5427caad95dac2ae6e198         1
#
#                                              transcript
# 0      Sir, how is the signature? Is it a hidden cop...
# 1      I have sent it in the morning. Yes, this amou...
# 2      Hello ma'am, I am Koshal speaking. Yes, pleas...
# 3      Good morning, Chester. I am Aishwarya. How ar...
# 4                Okay. Thank you so much for your time.
# ...                                                 ...
# 1357                                             Hello.
# 1358   So you have to fill in the segment, which seg...
# 1359   If you go to the Choice Phoenix App, then go ...
# 1360   No sir, you have to activate the segment for ...
# 1361   Good morning sir, this is Choice Phoenix, how...
#
# [1362 rows x 3 columns]
